# %%
import numpy as np
import pandas as pd
import json

# %%
dataframe=pd.read_json('kurzgesagt.json')

# %%
dataframe.head(50)
# Out:
#                                                 title     views  time_in_days
# 0   We Traveled Back in Time. Now Physicists Are A...   3600000             4
# 1      Fever Feels Horrible, but is Actually Awesome!   5000000            14
# 2                                    You're Not Ready    835000            21
# 3                  A.I. ‐ Humanity's Final Invention?   4600000            21
# 4   We Need to Rethink Exercise - The Workout Paradox   6700000            30
# 5            This Disease is Deadlier Than The Plague   7100000            60
# 6                            Do You Have a Free Will?   4600000            60
# 7                          We Are Making a VIDEO GAME   1500000            60
# 8                              Your Hidden Superpower   1000000            90
# 9   This Black Hole Could be Bigger Than The Universe   5200000            90
# 10                                 Smoking is Awesome  11000000            90
# ...
