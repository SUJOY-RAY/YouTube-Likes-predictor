# %%
import pandas as pd
import json

# %%
json_file_path = "checker1.json"  # Replace with the correct file path if necessary
with open(json_file_path, 'r') as file:
    data = json.load(file)

# %%
df=pd.DataFrame(data['videos'])

# %%
df.head()
# Out:
#                                      video title    views  days ago products  \
# 0         The Real Reason Why You Have Allergies  8000000        30       13
# 1             Is The World Getting More Violent?  8000000        30       11
# 2            Let's Talk About The Last 10 Months  3000000        30        9
# 3  Black Hole's Evil Twin - Gravastars Explained  2000000        30        9
# 4                  Vaping Is Too Good To Be True  6000000        60        7
#
#   duration
# 0    15:13
# 1    12:37
# 2     3:24
# 3     0:06
# 4    13:55
